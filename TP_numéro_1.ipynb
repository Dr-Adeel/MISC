# %% [markdown]
# Exercice 1

# %%
import math
r = 4.56
p = 2 * math.pi * r
a = math.pi * r**2
per = round(p,2)
area = round(a,2)
print(area)
print(per)
# Out:
# 65.33
# 28.65

# %% [markdown]
# Exercice 3

# %%
a = int(input("Entrer nombre "))
b = int(input("Entrer nombre "))
c = int(input("Entrer nombre "))
N = a
if b > N:
  N = b
if c > N:
  N = c
print("Le plus grand nombre est ", N)
# Out:
# Entrer nombre 1
# Entrer nombre 2
# Entrer nombre 3
# Le plus grand nombre est  3

# %% [markdown]
# Exercice 4

# %%
a = int(input("Enter l'age "))
if a > 5 and a < 10:
  print("Poussin ou Pupille")
elif a > 9 and a < 13:
  print("Minime ou Cadet")
elif a > 15 and a < 18:
  print("Junior")
elif a > 17:
  print("Senior")
else:
  print("Oups pas suffisamment grand")
# Out:
# Enter l'age 20
# Senior

# %% [markdown]
# Exercice 5

# %%
a = int(input("Enter un entier "))
category = ""
for i in range(0,8):
  if a == i:
    if i in [1,2,4,5]:
      category = "Ecole"
    elif i == 3:
      category = "Musique et Sport"
    elif i in [0,7]:
      category = "Repos"
print(category)
# Out:
# Enter un entier 7
# Repos

# %% [markdown]
# Exercice 6

# %%
d =int(input("Enter le numéro du jour "))
h = int(input("Enter l'heure "))
if d in [1,2,3,4,5,6]:
  if 8<=h<=17:
    print("Vrai")
  else:
    print("Faux")
elif d == 7:
  if 8<=h<=12:
    print("Vrai")
  else:
    print("Faux")
# Out:
# Enter le numéro du jour 5
# Enter l'heure 2
# Faux

# %% [markdown]
# Exercice 7

# %%
m = int(input("Enter un entier "))
j = int(input("Enter un entier "))
if (m==1 and j>=22) or m==1 or m==2 or(m==3 and j<=20):
  print("hiver")
elif (m==3 and j>=20) or m==4 or m==5 or(m==6 and j<=21):
  print("Primtemps")
elif (m==6 and j>=21) or m==7 or m==8 or(m==9 and j<=23):
  print("Eté")
elif (m==9 and j>=23) or m==10 or m==11 or(m==12 and j<=22):
  print("Automne")
# Out:
# Enter un entier 5
# Enter un entier 2
# Primtemps

# %% [markdown]
# Exercice 8

# %%
vdep = int(input("Enter un entier "))
vfin = int(input("Enter un entier "))
for i in range(vdep,vfin+1):
    print(i)
# Out:
# Enter un entier 2
# Enter un entier 5
# 2
# 3
# 4
# 5

# %% [markdown]
# Exercice 9

# %%
for i in range(1,10):
  for j in range(1,10):
    print(i*j)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 2
# 4
# 6
# 8
# 10
# 12
# 14
# 16
# 18
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 27
# 4
# 8
# 12
# 16
# 20
# 24
# 28
# 32
# 36
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 6
# 12
# 18
# 24
# 30
# 36
# 42
# 48
# 54
# 7
# 14
# 21
# 28
# 35
# 42
# 49
# 56
# 63
# 8
# 16
# 24
# 32
# 40
# 48
# 56
# 64
# 72
# 9
# 18
# 27
# 36
# 45
# 54
# 63
# 72
# 81

# %% [markdown]
# Exercice 10
# ---

# %%
n = int(input("Enter un entier "))
T = []
c = 0
for i in range(n, 0, -1):
  if n % i == 0:
    T.append(i)
    c = c + 1
print("{} ==> {} ==> {}".format(n, T, c))
# Out:
# Enter un entier 5
# 5 ==> [5, 1] ==> 2

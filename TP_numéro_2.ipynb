# %% [markdown]
# Exercice 1

# %%
def factoriel(n):
  liste = []
  r = 1
  if n==0:
    liste.append(1)
  for i in range(1,n+1):
    r *= i
    liste.append(r)
  return liste

# %%
factoriel(5)
# Out:
# [1, 2, 6, 24, 120]

# %%
print(len(str(factoriel(50))))
# Out:
# 1519

# %% [markdown]
# Exercice 2

# %%
def icarre(n):
  s = 0
  for i in range(n):
    imp = 2*i+1
    s += imp
  return s

# %%
icarre(5)
# Out:
# 25

# %% [markdown]
# Exercice 3

# %% [markdown]
# Question a

# %%
def mult0(a,b):
  s = 0
  for i in range(b):
    s += a
  return s

# %% [markdown]
# Question b

# %%
def signe(x):
  if x>0:
    return 1
  elif x<0:
    return -1
  else:
    return 0

# %%
def val_abs(x):
  if x<0:
    return -x
  else:
    return x

# %%
def mult(a,b):
  s = signe(a)*signe(b)
  if s < 0:
    return -mult0(val_abs(a),val_abs(b))
  else:
    return mult0(val_abs(a),val_abs(b))

# %% [markdown]
# Question c

# %%
print(mult(10,5))
mult(-21,-123)
# Out:
# 50
# 2583

# %% [markdown]
# Exercice 4

# %%
m = input("Entrer un mot")
e = " "
for i in m:
  e = e + i +" "
print(e)
# Out:
# Entrer un mot ubl
#  u b l

# %% [markdown]
# Exercice 5

# %%
def noccurs(lt, e):
    """Calcule le nombre de fois qu'un élément e apparaît dans une liste lt"""
    if not isinstance(lt, list):
        return -1

    compteur = 0
    for element in lt:
        if element == e:
            compteur += 1
    return compteur

# Tests
print("\nTests de la fonction noccurs:")
print(f'noccurs(["a",1,2,3,2,2,5,2], 2) = {noccurs(["a",1,2,3,2,2,5,2], 2)}')
print(f'noccurs(2, 2) = {noccurs(2, 2)}')
print(f'noccurs(["a",1,2,3,2,2,5,2], 9) = {noccurs(["a",1,2,3,2,2,5,2], 9)}')
# Out:
# Tests de la fonction noccurs:
# noccurs(["a",1,2,3,2,2,5,2], 2) = 4
# noccurs(2, 2) = -1
# noccurs(["a",1,2,3,2,2,5,2], 9) = 0

# %% [markdown]
# Exercice 6

# %%
n = int(input("\nEntrez un entier : "))

if n <= 0:
    liste_tirets = []
else:
    liste_tirets = []
    for i in range(1, n + 1):
        element = "$" + "-" * i + "$"
        liste_tirets.append(element)

print(f"Résultat : {liste_tirets}")
# Out:
# Entrez un entier :  5
# Résultat : ['$-$', '$--$', '$---$', '$----$', '$-----$']

# %% [markdown]
# Exercice 7

# %%
def traceMT(m):
    n = len(m)
    s = 0
    for i in range(n):
        s += m[i][i]
    return s
